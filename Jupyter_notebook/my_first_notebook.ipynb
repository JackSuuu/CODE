# %% [markdown]
# # This is a my first jupyter notebook on my Mac
#
# The notebook is running locally on the machine, first install the notebook by the command of `brew install jupyter`, after installation, then type the command of `jupyter notebook`, so the notebook will open the browser to connect to my local directory. And here is the interface of a ipynb file which consist of markdown and code.

# %%
import sympy

# %%
J, w = sympy.symbols('J,w')

# %%
J = w**2
J
# Out:
# w**2

# %%
sympy.diff(J,w)
# Out:
# 2*w

# %%
y, x = sympy.symbols('y,x')

# %%
y = sympy.cos(x)
y
# Out:
# cos(x)

# %%
sympy.diff(y)
